# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd

import pandas as pd
import numpy as np

data_df = pd.read_csv('./Resources/us_disaster.csv')
data_df.head()
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
# 1                 DR-2-TX                2    TX               DR
# 2                 DR-3-LA                3    LA               DR
# 3                 DR-4-MI                4    MI               DR
# 4                 DR-5-MT                5    MT               DR
#
#        declaration_date  fy_declared incident_type         declaration_title  \
# 0  1953-05-02T00:00:00Z         1953       Tornado                   Tornado
# 1  1953-05-15T00:00:00Z         1953       Tornado  Tornado & Heavy Rainfall
# 2  1953-05-29T00:00:00Z         1953         Flood                     Flood
# 3  1953-06-02T00:00:00Z         1953       Tornado                   Tornado
# 4  1953-06-06T00:00:00Z         1953         Flood                    Floods
#
#    ih_program_declared  ia_program_declared  ...     incident_end_date  \
# ...

# %%
# Topic 1: Identifying common types of natural disasters in different regions
plt.figure(figsize=(10, 6))
plt.title('Most Common Types of Natural Disasters by Region')
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

# Group the data by Region and Disaster Type, and count the occurrences
grouped_topic1 = df_topic1.groupby(['Region', 'Disaster Type']).size().unstack(fill_value=0)
colors = plt.cm.get_cmap('tab10').colors
grouped_topic1.plot(kind='bar', stacked=True, color=colors, ax=plt.gca())

plt.legend(title='Disaster Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Topic 2: Analyzing frequency and severity of disasters over the years
plt.figure(figsize=(10, 6))
plt.title('Frequency and Severity of Natural Disasters Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')

# Group the data by Year and calculate the sum of Frequency and mean of Severity
grouped_topic2 = df_topic2.groupby('Year').agg({'Frequency': 'sum', 'Severity': 'mean'}).reset_index()
plt.plot(grouped_topic2['Year'], grouped_topic2['Frequency'], label='Frequency', marker='o', color='b')
plt.plot(grouped_topic2['Year'], grouped_topic2['Severity'], label='Severity (mean)', marker='o', color='r')

plt.legend()

plt.show()
# Out:
# /var/folders/t1/18wjd24j1v3bs98g33bz6yh40000gn/T/ipykernel_22548/1382836372.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10').colors

# %%
# Generate sample data for topic 3: Examining financial impact of different types of natural disasters
financial_impact = np.random.randint(100000, 10000000, len(disaster_types))

data_topic3 = {
    'Disaster Type': disaster_types,
    'Financial Impact (in USD)': financial_impact,
}
df_topic3 = pd.DataFrame(data_topic3)

plt.figure(figsize=(10, 6))
plt.bar(df_topic3['Disaster Type'], df_topic3['Financial Impact (in USD)'])
plt.title('Financial Impact of Different Types of Natural Disasters')
plt.xlabel('Disaster Type')
plt.ylabel('Total Financial Impact (in USD)')
plt.xticks(rotation=45)
plt.show()

# %%
# Question 6: What are the main types of natural disasters included in the dataset, and how are they categorized?
disaster_types_count = df_topic1['incident_type'].nunique()
disaster_types_list = df_topic1['incident_type'].unique()

print(f"Number of unique disaster types: {disaster_types_count}")
print("List of unique disaster types:")
print(disaster_types_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'incident_type'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
converted_data_df = converted_data_df.rename(columns={"state": "State",
                                                "declaration_type": "Type of Declaration",
                                                "declaration_date": "Declaration Date",
                                                "fy_declared": "Fiscal Year Declared",
                                                "incident_type": "Incident Type",
                                                "declaration_title": "Title of Disaster",
                                                "ih_program_declared": "IH program",
                                                "ia_program_declared": "IA Program",
                                                "pa_program_declared": "PA program",
                                                "hm_program_declared": "HM program",
                                                "incident_begin_date": "Date Incident Began",
                                                "incident_end_date": "Date Incident Ended",
                                                "disaster_closeout_date": "Date all Fin. trans. completed",
                                                "designated_area": "County/Statewide",
                                                })
converted_data_df.head()
